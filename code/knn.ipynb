# %%
import pandas as pd
import warnings
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
tr_features = pd.read_csv('data/train_features.csv')
tr_labels = pd.read_csv('data/train_labels.csv')

te_features = pd.read_csv('data/test_features.csv')
te_labels = pd.read_csv('data/test_labels.csv')

# %%
def print_results(results):
    print(f'BEST PARAMS: {results.best_params_}\n')

    means = sorted(results.cv_results_['mean_test_score'], reverse=True)
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print(f'{round(mean,3)} (+/- {round(std * 2, 3)}) for {params}')

# %%
knn = KNeighborsClassifier()
rfscores = cross_val_score(knn, tr_features, tr_labels.values.ravel(), cv=5, n_jobs=32)
print(rfscores)
# Out:
# [0.28046666 0.29402491 0.29197541 0.29150244 0.29670503]

# %%
knnparams = {
    'n_neighbors': [1,3,5],
    'weights': ['uniform', 'distance'],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    'leaf_size': [10,20,30],
    'p': [1, 2, 3],
    # 'metric': ['minkowski', 'precomputed']
}

cv = GridSearchCV(knn, knnparams, cv=5, n_jobs=32)
cv.fit(tr_features, tr_labels.values.ravel())

print_results(cv)
# Out:
# BEST PARAMS: {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
#
# 0.299 (+/- 0.009) for {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}
# 0.299 (+/- 0.009) for {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 1, 'p': 1, 'weights': 'distance'}
# 0.299 (+/- 0.01) for {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 1, 'p': 2, 'weights': 'uniform'}
# 0.299 (+/- 0.01) for {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 1, 'p': 2, 'weights': 'distance'}
# 0.299 (+/- 0.01) for {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 1, 'p': 3, 'weights': 'uniform'}
# 0.299 (+/- 0.01) for {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 1, 'p': 3, 'weights': 'distance'}
# 0.299 (+/- 0.017) for {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.299 (+/- 0.011) for {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.299 (+/- 0.007) for {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.299 (+/- 0.01) for {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.299 (+/- 0.009) for {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.299 (+/- 0.01) for {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.299 (+/- 0.012) for {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.299 (+/- 0.009) for {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.299 (+/- 0.011) for {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.299 (+/- 0.009) for {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.299 (+/- 0.006) for {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.299 (+/- 0.009) for {'algorithm': 'auto', 'leaf_size': 10, 'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.299 (+/- 0.009) for {'algorithm': 'auto', 'leaf_size': 20, 'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}
# 0.299 (+/- 0.009) for {'algorithm': 'auto', 'leaf_size': 20, 'n_neighbors': 1, 'p': 1, 'weights': 'distance'}
# 0.299 (+/- 0.01) for {'algorithm': 'auto', 'leaf_size': 20, 'n_neighbors': 1, 'p': 2, 'weights': 'uniform'}
# 0.299 (+/- 0.01) for {'algorithm': 'auto', 'leaf_size': 20, 'n_neighbors': 1, 'p': 2, 'weights': 'distance'}
# 0.299 (+/- 0.01) for {'algorithm': 'auto', 'leaf_size': 20, 'n_neighbors': 1, 'p': 3, 'weights': 'uniform'}
# 0.299 (+/- 0.01) for {'algorithm': 'auto', 'leaf_size': 20, 'n_neighbors': 1, 'p': 3, 'weights': 'distance'}
# 0.294 (+/- 0.017) for {'algorithm': 'auto', 'leaf_size': 20, 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.294 (+/- 0.011) for {'algorithm': 'auto', 'leaf_size': 20, 'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.294 (+/- 0.007) for {'algorithm': 'auto', 'leaf_size': 20, 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.294 (+/- 0.01) for {'algorithm': 'auto', 'leaf_size': 20, 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.294 (+/- 0.009) for {'algorithm': 'auto', 'leaf_size': 20, 'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.294 (+/- 0.01) for {'algorithm': 'auto', 'leaf_size': 20, 'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.294 (+/- 0.012) for {'algorithm': 'auto', 'leaf_size': 20, 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.294 (+/- 0.009) for {'algorithm': 'auto', 'leaf_size': 20, 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.294 (+/- 0.011) for {'algorithm': 'auto', 'leaf_size': 20, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.294 (+/- 0.009) for {'algorithm': 'auto', 'leaf_size': 20, 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.294 (+/- 0.006) for {'algorithm': 'auto', 'leaf_size': 20, 'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.294 (+/- 0.009) for {'algorithm': 'auto', 'leaf_size': 20, 'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.292 (+/- 0.009) for {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}
# 0.292 (+/- 0.009) for {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 1, 'p': 1, 'weights': 'distance'}
# 0.292 (+/- 0.01) for {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 1, 'p': 2, 'weights': 'uniform'}
# 0.292 (+/- 0.01) for {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 1, 'p': 2, 'weights': 'distance'}
# 0.292 (+/- 0.01) for {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 1, 'p': 3, 'weights': 'uniform'}
# 0.292 (+/- 0.01) for {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 1, 'p': 3, 'weights': 'distance'}
# 0.292 (+/- 0.017) for {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.292 (+/- 0.011) for {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.292 (+/- 0.007) for {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.292 (+/- 0.01) for {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.292 (+/- 0.009) for {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.292 (+/- 0.01) for {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.291 (+/- 0.012) for {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.291 (+/- 0.009) for {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.291 (+/- 0.011) for {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.291 (+/- 0.009) for {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.291 (+/- 0.006) for {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.291 (+/- 0.009) for {'algorithm': 'auto', 'leaf_size': 30, 'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.291 (+/- 0.009) for {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}
# 0.291 (+/- 0.009) for {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 1, 'p': 1, 'weights': 'distance'}
# 0.291 (+/- 0.01) for {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 1, 'p': 2, 'weights': 'uniform'}
# 0.291 (+/- 0.01) for {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 1, 'p': 2, 'weights': 'distance'}
# 0.291 (+/- 0.01) for {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 1, 'p': 3, 'weights': 'uniform'}
# 0.291 (+/- 0.01) for {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 1, 'p': 3, 'weights': 'distance'}
# 0.291 (+/- 0.017) for {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.291 (+/- 0.011) for {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.291 (+/- 0.007) for {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.291 (+/- 0.01) for {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.291 (+/- 0.009) for {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.291 (+/- 0.01) for {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.291 (+/- 0.012) for {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.291 (+/- 0.009) for {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.291 (+/- 0.011) for {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.291 (+/- 0.009) for {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.291 (+/- 0.006) for {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.291 (+/- 0.009) for {'algorithm': 'ball_tree', 'leaf_size': 10, 'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.291 (+/- 0.009) for {'algorithm': 'ball_tree', 'leaf_size': 20, 'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}
# 0.291 (+/- 0.009) for {'algorithm': 'ball_tree', 'leaf_size': 20, 'n_neighbors': 1, 'p': 1, 'weights': 'distance'}
# 0.291 (+/- 0.01) for {'algorithm': 'ball_tree', 'leaf_size': 20, 'n_neighbors': 1, 'p': 2, 'weights': 'uniform'}
# 0.291 (+/- 0.01) for {'algorithm': 'ball_tree', 'leaf_size': 20, 'n_neighbors': 1, 'p': 2, 'weights': 'distance'}
# 0.291 (+/- 0.01) for {'algorithm': 'ball_tree', 'leaf_size': 20, 'n_neighbors': 1, 'p': 3, 'weights': 'uniform'}
# 0.291 (+/- 0.01) for {'algorithm': 'ball_tree', 'leaf_size': 20, 'n_neighbors': 1, 'p': 3, 'weights': 'distance'}
# 0.291 (+/- 0.017) for {'algorithm': 'ball_tree', 'leaf_size': 20, 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.291 (+/- 0.011) for {'algorithm': 'ball_tree', 'leaf_size': 20, 'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.291 (+/- 0.007) for {'algorithm': 'ball_tree', 'leaf_size': 20, 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.291 (+/- 0.01) for {'algorithm': 'ball_tree', 'leaf_size': 20, 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.291 (+/- 0.009) for {'algorithm': 'ball_tree', 'leaf_size': 20, 'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.291 (+/- 0.01) for {'algorithm': 'ball_tree', 'leaf_size': 20, 'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.289 (+/- 0.012) for {'algorithm': 'ball_tree', 'leaf_size': 20, 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.289 (+/- 0.009) for {'algorithm': 'ball_tree', 'leaf_size': 20, 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.289 (+/- 0.011) for {'algorithm': 'ball_tree', 'leaf_size': 20, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.289 (+/- 0.009) for {'algorithm': 'ball_tree', 'leaf_size': 20, 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.289 (+/- 0.006) for {'algorithm': 'ball_tree', 'leaf_size': 20, 'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.289 (+/- 0.009) for {'algorithm': 'ball_tree', 'leaf_size': 20, 'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.289 (+/- 0.009) for {'algorithm': 'ball_tree', 'leaf_size': 30, 'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}
# 0.289 (+/- 0.009) for {'algorithm': 'ball_tree', 'leaf_size': 30, 'n_neighbors': 1, 'p': 1, 'weights': 'distance'}
# 0.289 (+/- 0.01) for {'algorithm': 'ball_tree', 'leaf_size': 30, 'n_neighbors': 1, 'p': 2, 'weights': 'uniform'}
# 0.289 (+/- 0.01) for {'algorithm': 'ball_tree', 'leaf_size': 30, 'n_neighbors': 1, 'p': 2, 'weights': 'distance'}
# 0.289 (+/- 0.01) for {'algorithm': 'ball_tree', 'leaf_size': 30, 'n_neighbors': 1, 'p': 3, 'weights': 'uniform'}
# 0.289 (+/- 0.01) for {'algorithm': 'ball_tree', 'leaf_size': 30, 'n_neighbors': 1, 'p': 3, 'weights': 'distance'}
# 0.288 (+/- 0.017) for {'algorithm': 'ball_tree', 'leaf_size': 30, 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.288 (+/- 0.011) for {'algorithm': 'ball_tree', 'leaf_size': 30, 'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.288 (+/- 0.007) for {'algorithm': 'ball_tree', 'leaf_size': 30, 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.288 (+/- 0.01) for {'algorithm': 'ball_tree', 'leaf_size': 30, 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.288 (+/- 0.009) for {'algorithm': 'ball_tree', 'leaf_size': 30, 'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.288 (+/- 0.01) for {'algorithm': 'ball_tree', 'leaf_size': 30, 'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.288 (+/- 0.012) for {'algorithm': 'ball_tree', 'leaf_size': 30, 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.288 (+/- 0.009) for {'algorithm': 'ball_tree', 'leaf_size': 30, 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.288 (+/- 0.011) for {'algorithm': 'ball_tree', 'leaf_size': 30, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.288 (+/- 0.009) for {'algorithm': 'ball_tree', 'leaf_size': 30, 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.288 (+/- 0.006) for {'algorithm': 'ball_tree', 'leaf_size': 30, 'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.288 (+/- 0.009) for {'algorithm': 'ball_tree', 'leaf_size': 30, 'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.285 (+/- 0.009) for {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}
# 0.285 (+/- 0.009) for {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 1, 'p': 1, 'weights': 'distance'}
# 0.285 (+/- 0.01) for {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 1, 'p': 2, 'weights': 'uniform'}
# 0.285 (+/- 0.01) for {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 1, 'p': 2, 'weights': 'distance'}
# 0.285 (+/- 0.01) for {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 1, 'p': 3, 'weights': 'uniform'}
# 0.285 (+/- 0.01) for {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 1, 'p': 3, 'weights': 'distance'}
# 0.285 (+/- 0.017) for {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.285 (+/- 0.011) for {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.285 (+/- 0.007) for {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.285 (+/- 0.01) for {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.285 (+/- 0.009) for {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.285 (+/- 0.01) for {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.284 (+/- 0.012) for {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.284 (+/- 0.009) for {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.284 (+/- 0.011) for {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.284 (+/- 0.009) for {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.284 (+/- 0.006) for {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.284 (+/- 0.009) for {'algorithm': 'kd_tree', 'leaf_size': 10, 'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.284 (+/- 0.009) for {'algorithm': 'kd_tree', 'leaf_size': 20, 'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}
# 0.284 (+/- 0.009) for {'algorithm': 'kd_tree', 'leaf_size': 20, 'n_neighbors': 1, 'p': 1, 'weights': 'distance'}
# 0.284 (+/- 0.01) for {'algorithm': 'kd_tree', 'leaf_size': 20, 'n_neighbors': 1, 'p': 2, 'weights': 'uniform'}
# 0.284 (+/- 0.01) for {'algorithm': 'kd_tree', 'leaf_size': 20, 'n_neighbors': 1, 'p': 2, 'weights': 'distance'}
# 0.284 (+/- 0.01) for {'algorithm': 'kd_tree', 'leaf_size': 20, 'n_neighbors': 1, 'p': 3, 'weights': 'uniform'}
# 0.284 (+/- 0.01) for {'algorithm': 'kd_tree', 'leaf_size': 20, 'n_neighbors': 1, 'p': 3, 'weights': 'distance'}
# 0.284 (+/- 0.017) for {'algorithm': 'kd_tree', 'leaf_size': 20, 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.284 (+/- 0.011) for {'algorithm': 'kd_tree', 'leaf_size': 20, 'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.284 (+/- 0.007) for {'algorithm': 'kd_tree', 'leaf_size': 20, 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.284 (+/- 0.01) for {'algorithm': 'kd_tree', 'leaf_size': 20, 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.284 (+/- 0.009) for {'algorithm': 'kd_tree', 'leaf_size': 20, 'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.284 (+/- 0.01) for {'algorithm': 'kd_tree', 'leaf_size': 20, 'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.284 (+/- 0.012) for {'algorithm': 'kd_tree', 'leaf_size': 20, 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.284 (+/- 0.009) for {'algorithm': 'kd_tree', 'leaf_size': 20, 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.284 (+/- 0.011) for {'algorithm': 'kd_tree', 'leaf_size': 20, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.284 (+/- 0.009) for {'algorithm': 'kd_tree', 'leaf_size': 20, 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.284 (+/- 0.006) for {'algorithm': 'kd_tree', 'leaf_size': 20, 'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.284 (+/- 0.009) for {'algorithm': 'kd_tree', 'leaf_size': 20, 'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.284 (+/- 0.009) for {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}
# 0.284 (+/- 0.009) for {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_neighbors': 1, 'p': 1, 'weights': 'distance'}
# 0.284 (+/- 0.01) for {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_neighbors': 1, 'p': 2, 'weights': 'uniform'}
# 0.284 (+/- 0.01) for {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_neighbors': 1, 'p': 2, 'weights': 'distance'}
# 0.284 (+/- 0.01) for {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_neighbors': 1, 'p': 3, 'weights': 'uniform'}
# 0.284 (+/- 0.01) for {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_neighbors': 1, 'p': 3, 'weights': 'distance'}
# 0.284 (+/- 0.017) for {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.284 (+/- 0.011) for {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.284 (+/- 0.007) for {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.284 (+/- 0.01) for {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.284 (+/- 0.009) for {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.284 (+/- 0.01) for {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.283 (+/- 0.012) for {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.283 (+/- 0.009) for {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.283 (+/- 0.011) for {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.283 (+/- 0.009) for {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.283 (+/- 0.006) for {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.283 (+/- 0.009) for {'algorithm': 'kd_tree', 'leaf_size': 30, 'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.283 (+/- 0.009) for {'algorithm': 'brute', 'leaf_size': 10, 'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}
# 0.283 (+/- 0.009) for {'algorithm': 'brute', 'leaf_size': 10, 'n_neighbors': 1, 'p': 1, 'weights': 'distance'}
# 0.283 (+/- 0.01) for {'algorithm': 'brute', 'leaf_size': 10, 'n_neighbors': 1, 'p': 2, 'weights': 'uniform'}
# 0.283 (+/- 0.01) for {'algorithm': 'brute', 'leaf_size': 10, 'n_neighbors': 1, 'p': 2, 'weights': 'distance'}
# 0.283 (+/- 0.01) for {'algorithm': 'brute', 'leaf_size': 10, 'n_neighbors': 1, 'p': 3, 'weights': 'uniform'}
# 0.283 (+/- 0.01) for {'algorithm': 'brute', 'leaf_size': 10, 'n_neighbors': 1, 'p': 3, 'weights': 'distance'}
# 0.281 (+/- 0.017) for {'algorithm': 'brute', 'leaf_size': 10, 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.281 (+/- 0.011) for {'algorithm': 'brute', 'leaf_size': 10, 'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.281 (+/- 0.007) for {'algorithm': 'brute', 'leaf_size': 10, 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.281 (+/- 0.01) for {'algorithm': 'brute', 'leaf_size': 10, 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.281 (+/- 0.009) for {'algorithm': 'brute', 'leaf_size': 10, 'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.281 (+/- 0.01) for {'algorithm': 'brute', 'leaf_size': 10, 'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.281 (+/- 0.012) for {'algorithm': 'brute', 'leaf_size': 10, 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.281 (+/- 0.009) for {'algorithm': 'brute', 'leaf_size': 10, 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.281 (+/- 0.011) for {'algorithm': 'brute', 'leaf_size': 10, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.281 (+/- 0.009) for {'algorithm': 'brute', 'leaf_size': 10, 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.281 (+/- 0.006) for {'algorithm': 'brute', 'leaf_size': 10, 'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.281 (+/- 0.009) for {'algorithm': 'brute', 'leaf_size': 10, 'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.281 (+/- 0.009) for {'algorithm': 'brute', 'leaf_size': 20, 'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}
# 0.281 (+/- 0.009) for {'algorithm': 'brute', 'leaf_size': 20, 'n_neighbors': 1, 'p': 1, 'weights': 'distance'}
# 0.281 (+/- 0.01) for {'algorithm': 'brute', 'leaf_size': 20, 'n_neighbors': 1, 'p': 2, 'weights': 'uniform'}
# 0.281 (+/- 0.01) for {'algorithm': 'brute', 'leaf_size': 20, 'n_neighbors': 1, 'p': 2, 'weights': 'distance'}
# 0.281 (+/- 0.01) for {'algorithm': 'brute', 'leaf_size': 20, 'n_neighbors': 1, 'p': 3, 'weights': 'uniform'}
# 0.281 (+/- 0.01) for {'algorithm': 'brute', 'leaf_size': 20, 'n_neighbors': 1, 'p': 3, 'weights': 'distance'}
# 0.281 (+/- 0.017) for {'algorithm': 'brute', 'leaf_size': 20, 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.281 (+/- 0.011) for {'algorithm': 'brute', 'leaf_size': 20, 'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.281 (+/- 0.007) for {'algorithm': 'brute', 'leaf_size': 20, 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.281 (+/- 0.01) for {'algorithm': 'brute', 'leaf_size': 20, 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.281 (+/- 0.009) for {'algorithm': 'brute', 'leaf_size': 20, 'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.281 (+/- 0.01) for {'algorithm': 'brute', 'leaf_size': 20, 'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.279 (+/- 0.012) for {'algorithm': 'brute', 'leaf_size': 20, 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.279 (+/- 0.009) for {'algorithm': 'brute', 'leaf_size': 20, 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.279 (+/- 0.011) for {'algorithm': 'brute', 'leaf_size': 20, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.279 (+/- 0.009) for {'algorithm': 'brute', 'leaf_size': 20, 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.279 (+/- 0.006) for {'algorithm': 'brute', 'leaf_size': 20, 'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.279 (+/- 0.009) for {'algorithm': 'brute', 'leaf_size': 20, 'n_neighbors': 5, 'p': 3, 'weights': 'distance'}
# 0.279 (+/- 0.009) for {'algorithm': 'brute', 'leaf_size': 30, 'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}
# 0.279 (+/- 0.009) for {'algorithm': 'brute', 'leaf_size': 30, 'n_neighbors': 1, 'p': 1, 'weights': 'distance'}
# 0.279 (+/- 0.01) for {'algorithm': 'brute', 'leaf_size': 30, 'n_neighbors': 1, 'p': 2, 'weights': 'uniform'}
# 0.279 (+/- 0.01) for {'algorithm': 'brute', 'leaf_size': 30, 'n_neighbors': 1, 'p': 2, 'weights': 'distance'}
# 0.279 (+/- 0.01) for {'algorithm': 'brute', 'leaf_size': 30, 'n_neighbors': 1, 'p': 3, 'weights': 'uniform'}
# 0.279 (+/- 0.01) for {'algorithm': 'brute', 'leaf_size': 30, 'n_neighbors': 1, 'p': 3, 'weights': 'distance'}
# 0.279 (+/- 0.017) for {'algorithm': 'brute', 'leaf_size': 30, 'n_neighbors': 3, 'p': 1, 'weights': 'uniform'}
# 0.279 (+/- 0.011) for {'algorithm': 'brute', 'leaf_size': 30, 'n_neighbors': 3, 'p': 1, 'weights': 'distance'}
# 0.279 (+/- 0.007) for {'algorithm': 'brute', 'leaf_size': 30, 'n_neighbors': 3, 'p': 2, 'weights': 'uniform'}
# 0.279 (+/- 0.01) for {'algorithm': 'brute', 'leaf_size': 30, 'n_neighbors': 3, 'p': 2, 'weights': 'distance'}
# 0.279 (+/- 0.009) for {'algorithm': 'brute', 'leaf_size': 30, 'n_neighbors': 3, 'p': 3, 'weights': 'uniform'}
# 0.279 (+/- 0.01) for {'algorithm': 'brute', 'leaf_size': 30, 'n_neighbors': 3, 'p': 3, 'weights': 'distance'}
# 0.279 (+/- 0.012) for {'algorithm': 'brute', 'leaf_size': 30, 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}
# 0.279 (+/- 0.009) for {'algorithm': 'brute', 'leaf_size': 30, 'n_neighbors': 5, 'p': 1, 'weights': 'distance'}
# 0.279 (+/- 0.011) for {'algorithm': 'brute', 'leaf_size': 30, 'n_neighbors': 5, 'p': 2, 'weights': 'uniform'}
# 0.279 (+/- 0.009) for {'algorithm': 'brute', 'leaf_size': 30, 'n_neighbors': 5, 'p': 2, 'weights': 'distance'}
# 0.279 (+/- 0.006) for {'algorithm': 'brute', 'leaf_size': 30, 'n_neighbors': 5, 'p': 3, 'weights': 'uniform'}
# 0.279 (+/- 0.009) for {'algorithm': 'brute', 'leaf_size': 30, 'n_neighbors': 5, 'p': 3, 'weights': 'distance'}

# %%
knn.fit(tr_features, tr_labels.values.ravel())
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(te_features)
accuracy = round(accuracy_score(te_labels, y_pred), 8)
precision = round(precision_score(te_labels, y_pred, average='weighted'), 8)
recall = round(recall_score(te_labels, y_pred, average='weighted'), 8)
f1 = round(f1_score(te_labels, y_pred, average='weighted'), 8)
print(f'LEAF SIZE: {knn.leaf_size} / NEAREST NEIGHBOURS: {knn.n_neighbors} / A: {accuracy} / P: {precision} / R: {recall} / F1: {f1}')
# Out:
# LEAF SIZE: 30 / NEAREST NEIGHBOURS: 5 / A: 0.29940724 / P: 0.30193629 / R: 0.29940724 / F1: 0.29542616
