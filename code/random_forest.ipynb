# %%
import pandas as pd
import warnings
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
tr_features = pd.read_csv('data/train_features.csv')
tr_labels = pd.read_csv('data/train_labels.csv')

te_features = pd.read_csv('data/test_features.csv')
te_labels = pd.read_csv('data/test_labels.csv')

# %%
def print_results(results):
    print(f'BEST PARAMS: {results.best_params_}\n')

    means = sorted(results.cv_results_['mean_test_score'], reverse=True)
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print(f'{round(mean,3)} (+/- {round(std * 2, 3)}) for {params}')

# %%
rf = RandomForestClassifier()
rfscores = cross_val_score(rf, tr_features, tr_labels.values.ravel(), cv=5, n_jobs=16)
print(rfscores)
# Out:
# [0.37773924 0.38893268 0.38010405 0.38909034 0.38514898]

# %%
rfparams = {
    'n_estimators': [25, 50],
    'max_depth': [5, 50, 100, None],
    'min_samples_leaf': [3],
    'max_features': ['sqrt', 'log2', None],
    'max_leaf_nodes': [5, 50, 500, None],
    'bootstrap': [True, False],
    'oob_score': [True, False],
    'warm_start': [True, False],
    'max_samples': [None, 1, 2]
}
cv = GridSearchCV(rf, rfparams, cv=5, n_jobs=16)
cv.fit(tr_features, tr_labels.values.ravel())

print_results(cv)
# Out:
# c:\Users\caden\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 4800 fits failed out of a total of 11520.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 960 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\caden\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\caden\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py", line 434, in fit
#     raise ValueError("Out of bag estimation only available if bootstrap=True")
# ValueError: Out of bag estimation only available if bootstrap=True
#
# --------------------------------------------------------------------------------
# 3840 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\caden\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\caden\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_forest.py", line 397, in fit
#     raise ValueError(
# ValueError: `max_sample` cannot be set if `bootstrap=False`. Either switch to `bootstrap=True` or set `max_sample=None`.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# c:\Users\caden\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.35872615 0.36017657 0.36200536 ...        nan        nan        nan]
#   warnings.warn(
# BEST PARAMS: {'bootstrap': False, 'max_depth': 100, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
#
# 0.39 (+/- 0.011) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.39 (+/- 0.013) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.389 (+/- 0.014) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.389 (+/- 0.014) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.389 (+/- 0.014) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.389 (+/- 0.011) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.388 (+/- 0.014) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.388 (+/- 0.011) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.388 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.388 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.388 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.388 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.388 (+/- 0.007) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.388 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.387 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.387 (+/- 0.011) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.387 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.387 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.387 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.386 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.386 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.386 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.386 (+/- 0.003) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.386 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.386 (+/- 0.007) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.386 (+/- 0.007) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.386 (+/- 0.017) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.386 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.386 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.386 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.385 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.385 (+/- 0.013) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.385 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.385 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.385 (+/- 0.011) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.385 (+/- 0.004) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.385 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.385 (+/- 0.003) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.384 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.384 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.384 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.384 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.384 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.384 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.384 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.384 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.384 (+/- 0.003) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.384 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.384 (+/- 0.007) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.384 (+/- 0.013) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.384 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.383 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.383 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.383 (+/- 0.015) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.383 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.383 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.383 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.383 (+/- 0.007) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.383 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.383 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.383 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.383 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.383 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.383 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.383 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.383 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.383 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.383 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.382 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.382 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.382 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.382 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.382 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.382 (+/- 0.011) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.382 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.382 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.382 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.382 (+/- 0.011) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.382 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.382 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.382 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.382 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.382 (+/- 0.011) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.382 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.382 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.382 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.382 (+/- 0.011) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.382 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.382 (+/- 0.011) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.382 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.382 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.382 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.381 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.381 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.381 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.381 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.381 (+/- 0.007) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.381 (+/- 0.014) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.381 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.381 (+/- 0.013) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.381 (+/- 0.015) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.381 (+/- 0.016) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.381 (+/- 0.013) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.381 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.381 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.381 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.381 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.381 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.381 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.381 (+/- 0.011) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.381 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.381 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.381 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.38 (+/- 0.003) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.38 (+/- 0.011) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.38 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.38 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.38 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.38 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.38 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.38 (+/- 0.011) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.38 (+/- 0.013) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.38 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.38 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.38 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.38 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.38 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.38 (+/- 0.011) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.38 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.38 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.38 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.38 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.38 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.38 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.379 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.379 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.379 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.379 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.379 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.379 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.379 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.379 (+/- 0.003) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.379 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.379 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.379 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.379 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.379 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.379 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.379 (+/- 0.015) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.379 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.379 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.379 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.379 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.379 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.379 (+/- 0.007) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.379 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.379 (+/- 0.003) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.379 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.379 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.379 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.379 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.378 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.378 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.378 (+/- 0.011) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.378 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.378 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.378 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.378 (+/- 0.003) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.378 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.378 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.378 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.378 (+/- 0.013) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.378 (+/- 0.017) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.378 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.377 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.377 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.377 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.377 (+/- 0.003) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.377 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.377 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.377 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.377 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.377 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.377 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.377 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.377 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.377 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.377 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.377 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.377 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.377 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.377 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.377 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.377 (+/- 0.007) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.377 (+/- 0.011) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.377 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.377 (+/- 0.014) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.377 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.377 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.377 (+/- 0.01) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.376 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.376 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.376 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.376 (+/- 0.007) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.376 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.376 (+/- 0.003) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.376 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.376 (+/- 0.003) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.376 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.376 (+/- 0.003) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.376 (+/- 0.012) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.376 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.376 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.376 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.376 (+/- 0.006) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.376 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# 0.376 (+/- 0.009) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# 0.375 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.375 (+/- 0.005) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.375 (+/- 0.007) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# 0.375 (+/- 0.008) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# 0.375 (+/- 0.007) for {'bootstrap': True, 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# ...
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 5, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.364 (+/- 0.009) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.364 (+/- 0.009) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.364 (+/- 0.009) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.364 (+/- 0.009) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 50, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.349 (+/- 0.005) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.349 (+/- 0.005) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.349 (+/- 0.005) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.349 (+/- 0.005) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': 500, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# 0.313 (+/- 0.01) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# 0.312 (+/- 0.01) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# 0.313 (+/- 0.009) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# 0.312 (+/- 0.01) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': None, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': 1, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': True, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 25, 'oob_score': False, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': True, 'warm_start': False}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': True}
# nan (+/- nan) for {'bootstrap': False, 'max_depth': None, 'max_features': None, 'max_leaf_nodes': None, 'max_samples': 2, 'min_samples_leaf': 3, 'n_estimators': 50, 'oob_score': False, 'warm_start': False}

# %%
rf.fit(tr_features, tr_labels.values.ravel())
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(te_features)
accuracy = round(accuracy_score(te_labels, y_pred), 8)
precision = round(precision_score(te_labels, y_pred, average='weighted'), 8)
recall = round(recall_score(te_labels, y_pred, average='weighted'), 8)
f1 = round(f1_score(te_labels, y_pred, average='weighted'), 8)
print(f'A: {accuracy} / P: {precision} / R: {recall} / F1: {f1}')
# Out:
# A: 0.38479001 / P: 0.37745289 / R: 0.38479001 / F1: 0.37824485
