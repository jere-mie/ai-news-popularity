# %%
import pandas as pd
import warnings
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
tr_features = pd.read_csv('data/train_features.csv')
tr_labels = pd.read_csv('data/train_labels.csv')

te_features = pd.read_csv('data/test_features.csv')
te_labels = pd.read_csv('data/test_labels.csv')

# %%
def print_results(results):
    print(f'BEST PARAMS: {results.best_params_}\n')

    means = sorted(results.cv_results_['mean_test_score'], reverse=True)
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print(f'{round(mean,3)} (+/- {round(std * 2, 3)}) for {params}')

# %%
rf = RandomForestClassifier()
rfscores = cross_val_score(rf, tr_features, tr_labels.values.ravel(), cv=5, n_jobs=-1)
print(rfscores)
rf.fit(tr_features, tr_labels.values.ravel())
# Out:
# [0.38041936 0.39602712 0.37017184 0.38010405 0.38483367]
# RandomForestClassifier()

# %%
rfparams = {
    'n_estimators': [25, 50],
    'max_depth': [5, 50, 100, None],
    'min_samples_leaf': [3],
    'max_features': ['sqrt', 'log2', None],
    'max_leaf_nodes': [5, 50, 500, None],
    'bootstrap': [True, False],
    'oob_score': [True, False],
    'warm_start': [True, False],
    'max_samples': [None, 1, 2]
}
cv = GridSearchCV(rf, rfparams, cv=5, n_jobs=-1)
cv.fit(tr_features, tr_labels.values.ravel())

print_results(cv)
# Out:
# c:\Users\zhutz\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 4800 fits failed out of a total of 11520.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 960 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\zhutz\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\zhutz\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_forest.py", line 435, in fit
#     raise ValueError("Out of bag estimation only available if bootstrap=True")
# ...

# %%
rf0 = RandomForestClassifier(bootstrap=False, max_depth=None, max_features='log2', max_leaf_nodes=500, max_samples=None, min_samples_leaf=3, n_estimators=50, oob_score=False, warm_start=True)
rf0scores = cross_val_score(rf0, tr_features, tr_labels.values.ravel(), cv=5, n_jobs=-1)
print(rf0scores)
rf0.fit(tr_features, tr_labels.values.ravel())

# best params
rf1 = RandomForestClassifier(bootstrap=False, max_depth=100, max_features='sqrt', max_leaf_nodes=500, max_samples=None, min_samples_leaf=3, n_estimators=50, oob_score=False, warm_start=False)
rf1scores = cross_val_score(rf1, tr_features, tr_labels.values.ravel(), cv=5, n_jobs=-1)
print(rf1scores)
rf1.fit(tr_features, tr_labels.values.ravel())
# Out:
# [0.3840454  0.40154501 0.38436071 0.39381996 0.39019391]
# [0.38420306 0.40138736 0.38215356 0.39145515 0.39255873]
# RandomForestClassifier(bootstrap=False, max_depth=100, max_leaf_nodes=500,
#                        min_samples_leaf=3, n_estimators=50)

# %%
for mdl in [rf, rf0, rf1]:
    y_pred = mdl.predict(te_features)
    accuracy = round(accuracy_score(te_labels, y_pred), 8)
    precision = round(precision_score(te_labels, y_pred, average='weighted'), 8)
    recall = round(recall_score(te_labels, y_pred, average='weighted'), 8)
    f1 = round(f1_score(te_labels, y_pred, average='weighted'), 8)
    print(f'A: {accuracy} / P: {precision} / R: {recall} / F1: {f1}')
# Out:
# A: 0.39399672 / P: 0.38631685 / R: 0.39399672 / F1: 0.38774427
# A: 0.39954597 / P: 0.38868254 / R: 0.39954597 / F1: 0.38457263
# A: 0.40030269 / P: 0.39050577 / R: 0.40030269 / F1: 0.38685003
