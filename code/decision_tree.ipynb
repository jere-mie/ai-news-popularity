# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
pd.set_option('display.max_columns', None)

# %%
tr_features = pd.read_csv('data/train_features.csv')
tr_labels = pd.read_csv('data/train_labels.csv')

te_features = pd.read_csv('data/test_features.csv')
te_labels = pd.read_csv('data/test_labels.csv')

# %%
def print_results(results):
    print(f'BEST PARAMS: {results.best_params_}\n')

    means = sorted(results.cv_results_['mean_test_score'], reverse=True)
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print(f'{round(mean,3)} (+/- {round(std * 2, 3)}) for {params}')

# %%
dt = DecisionTreeClassifier()
dtscores = cross_val_score(dt, tr_features, tr_labels.values.ravel(), cv=5, n_jobs=-1)
print(dtscores)

dt.fit(tr_features, tr_labels.values.ravel())
# Out:
# [0.30096169 0.31420464 0.30900205 0.31152452 0.30269589]
# DecisionTreeClassifier()

# %%
dtparams = {
    'criterion': ['gini','entropy','log_loss'],
    'splitter': ['best','random'],
    'max_depth': [5,50,100,None],
    'max_leaf_nodes': [5,50,500,None],
    'min_samples_split': [1,2,3],
    'min_samples_leaf': [1,2,3],
    'max_features': [None,'sqrt','log2']
}

cv = GridSearchCV(dt, dtparams, cv=5, n_jobs=-1)
cv.fit(tr_features, tr_labels.values.ravel())

print_results(cv)
# Out:
# BEST PARAMS: {'criterion': 'entropy', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
#
# 0.367 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
# 0.367 (+/- 0.006) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
# 0.367 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.367 (+/- 0.013) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.367 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.367 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.367 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
# 0.367 (+/- 0.016) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
# 0.367 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.367 (+/- 0.008) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.367 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.367 (+/- 0.01) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.367 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'best'}
# 0.367 (+/- 0.01) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'random'}
# 0.367 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.367 (+/- 0.012) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.367 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.367 (+/- 0.012) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.367 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
# 0.367 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
# 0.367 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.367 (+/- 0.012) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.367 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.367 (+/- 0.02) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.367 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
# 0.367 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
# 0.367 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.367 (+/- 0.016) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.367 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.367 (+/- 0.012) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.367 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'best'}
# 0.367 (+/- 0.017) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'random'}
# 0.367 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.367 (+/- 0.008) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.367 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.367 (+/- 0.006) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.367 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
# 0.367 (+/- 0.019) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
# 0.367 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.367 (+/- 0.015) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.367 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.367 (+/- 0.01) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.367 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
# 0.367 (+/- 0.016) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
# 0.367 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.367 (+/- 0.006) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.367 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.367 (+/- 0.014) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.367 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'best'}
# 0.367 (+/- 0.014) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'random'}
# 0.367 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.367 (+/- 0.011) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.367 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.367 (+/- 0.008) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.364 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
# 0.364 (+/- 0.011) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
# 0.364 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.364 (+/- 0.012) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.364 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.364 (+/- 0.02) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.364 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
# 0.364 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
# 0.364 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.364 (+/- 0.005) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.364 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.364 (+/- 0.012) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.364 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'best'}
# 0.364 (+/- 0.01) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'random'}
# 0.364 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.364 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.364 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.364 (+/- 0.01) for {'criterion': 'gini', 'max_depth': 5, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.364 (+/- 0.02) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
# 0.364 (+/- 0.033) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
# 0.364 (+/- 0.029) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.364 (+/- 0.016) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.364 (+/- 0.015) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.364 (+/- 0.025) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.364 (+/- 0.008) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
# 0.364 (+/- 0.028) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
# 0.364 (+/- 0.014) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.363 (+/- 0.013) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.362 (+/- 0.014) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.362 (+/- 0.029) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.362 (+/- 0.026) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'best'}
# 0.362 (+/- 0.021) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'random'}
# 0.362 (+/- 0.022) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.362 (+/- 0.039) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.361 (+/- 0.017) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.361 (+/- 0.022) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.361 (+/- 0.014) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
# 0.361 (+/- 0.027) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
# 0.361 (+/- 0.013) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.361 (+/- 0.015) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.361 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.361 (+/- 0.026) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.361 (+/- 0.018) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
# 0.36 (+/- 0.018) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
# 0.36 (+/- 0.013) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.36 (+/- 0.015) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.36 (+/- 0.017) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.36 (+/- 0.016) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.36 (+/- 0.02) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'best'}
# 0.36 (+/- 0.017) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'random'}
# 0.36 (+/- 0.011) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.36 (+/- 0.018) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.36 (+/- 0.02) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.36 (+/- 0.017) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.359 (+/- 0.011) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
# 0.359 (+/- 0.033) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
# 0.359 (+/- 0.017) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.359 (+/- 0.024) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.359 (+/- 0.019) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.359 (+/- 0.025) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.359 (+/- 0.012) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
# 0.359 (+/- 0.011) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
# 0.359 (+/- 0.016) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.359 (+/- 0.019) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.359 (+/- 0.018) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.359 (+/- 0.013) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.359 (+/- 0.008) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'best'}
# 0.358 (+/- 0.022) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'random'}
# 0.358 (+/- 0.017) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.358 (+/- 0.019) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.358 (+/- 0.017) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.358 (+/- 0.021) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.358 (+/- 0.021) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
# 0.358 (+/- 0.011) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
# 0.358 (+/- 0.016) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.358 (+/- 0.027) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.358 (+/- 0.02) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.358 (+/- 0.019) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.358 (+/- 0.017) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
# 0.358 (+/- 0.02) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
# 0.358 (+/- 0.025) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.358 (+/- 0.023) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.358 (+/- 0.012) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.358 (+/- 0.02) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.358 (+/- 0.01) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'best'}
# 0.358 (+/- 0.027) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'random'}
# 0.358 (+/- 0.014) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.358 (+/- 0.006) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.358 (+/- 0.015) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.358 (+/- 0.022) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.358 (+/- 0.015) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
# 0.358 (+/- 0.024) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
# 0.358 (+/- 0.04) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.358 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.358 (+/- 0.015) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.358 (+/- 0.027) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.358 (+/- 0.018) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
# 0.358 (+/- 0.016) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
# 0.358 (+/- 0.017) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.358 (+/- 0.021) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.358 (+/- 0.017) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.358 (+/- 0.032) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.358 (+/- 0.028) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'best'}
# 0.358 (+/- 0.024) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'random'}
# 0.358 (+/- 0.023) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.358 (+/- 0.013) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.358 (+/- 0.015) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.358 (+/- 0.027) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.358 (+/- 0.018) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
# 0.358 (+/- 0.027) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
# 0.358 (+/- 0.014) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.358 (+/- 0.014) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.358 (+/- 0.029) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.358 (+/- 0.027) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.358 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
# 0.358 (+/- 0.018) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
# 0.358 (+/- 0.008) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.358 (+/- 0.024) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.358 (+/- 0.019) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.358 (+/- 0.027) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.358 (+/- 0.016) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'best'}
# 0.358 (+/- 0.02) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'random'}
# 0.358 (+/- 0.037) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.358 (+/- 0.022) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.358 (+/- 0.012) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.358 (+/- 0.029) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.358 (+/- 0.023) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
# 0.358 (+/- 0.025) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
# 0.358 (+/- 0.014) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.358 (+/- 0.01) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.358 (+/- 0.02) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.358 (+/- 0.028) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.358 (+/- 0.012) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
# 0.358 (+/- 0.013) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
# 0.358 (+/- 0.014) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.358 (+/- 0.026) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.358 (+/- 0.011) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.358 (+/- 0.029) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.358 (+/- 0.014) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'best'}
# 0.358 (+/- 0.023) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'random'}
# 0.358 (+/- 0.014) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.358 (+/- 0.027) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.358 (+/- 0.016) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.358 (+/- 0.014) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.358 (+/- 0.023) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
# 0.358 (+/- 0.023) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
# 0.358 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.358 (+/- 0.028) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.358 (+/- 0.028) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.358 (+/- 0.02) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.358 (+/- 0.013) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
# 0.358 (+/- 0.015) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
# 0.358 (+/- 0.022) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.358 (+/- 0.023) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.358 (+/- 0.015) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.358 (+/- 0.025) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.358 (+/- 0.023) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'best'}
# 0.358 (+/- 0.027) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'random'}
# 0.358 (+/- 0.026) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.358 (+/- 0.022) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.358 (+/- 0.027) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.358 (+/- 0.011) for {'criterion': 'gini', 'max_depth': 5, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.358 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
# 0.358 (+/- 0.01) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
# 0.358 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.358 (+/- 0.017) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.358 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.358 (+/- 0.013) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.357 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
# 0.357 (+/- 0.01) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
# 0.357 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.357 (+/- 0.017) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.357 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.357 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.357 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'best'}
# 0.357 (+/- 0.019) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'random'}
# 0.357 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.357 (+/- 0.013) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.357 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.357 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.357 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
# 0.357 (+/- 0.01) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
# 0.356 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.356 (+/- 0.004) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.356 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.356 (+/- 0.005) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.356 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
# 0.356 (+/- 0.004) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
# 0.356 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.356 (+/- 0.008) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.356 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.356 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.356 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'best'}
# 0.356 (+/- 0.013) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'random'}
# 0.356 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.356 (+/- 0.01) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.356 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.356 (+/- 0.01) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.356 (+/- 0.005) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
# 0.356 (+/- 0.01) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
# 0.356 (+/- 0.004) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.356 (+/- 0.01) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.355 (+/- 0.004) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.355 (+/- 0.008) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.355 (+/- 0.004) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
# 0.355 (+/- 0.02) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
# 0.355 (+/- 0.005) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.355 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.355 (+/- 0.005) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.355 (+/- 0.012) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.355 (+/- 0.005) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'best'}
# 0.355 (+/- 0.005) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'random'}
# 0.355 (+/- 0.005) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.354 (+/- 0.01) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.354 (+/- 0.004) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.354 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.354 (+/- 0.009) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
# 0.354 (+/- 0.007) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
# 0.354 (+/- 0.004) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.354 (+/- 0.008) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.354 (+/- 0.002) for {'criterion': 'gini', 'max_depth': 50, 'max_features': None, 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# ...
# 0.296 (+/- 0.008) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.296 (+/- 0.009) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.296 (+/- 0.009) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.296 (+/- 0.01) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.295 (+/- 0.019) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
# 0.295 (+/- 0.011) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
# 0.295 (+/- 0.02) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.295 (+/- 0.012) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.295 (+/- 0.018) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.295 (+/- 0.014) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.295 (+/- 0.003) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'best'}
# 0.295 (+/- 0.011) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'random'}
# 0.295 (+/- 0.011) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.295 (+/- 0.012) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.295 (+/- 0.008) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.295 (+/- 0.007) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'sqrt', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.295 (+/- 0.015) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
# 0.295 (+/- 0.012) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
# 0.295 (+/- 0.024) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.295 (+/- 0.024) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.295 (+/- 0.009) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.295 (+/- 0.02) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.295 (+/- 0.024) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
# 0.294 (+/- 0.008) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
# 0.294 (+/- 0.019) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.294 (+/- 0.022) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.294 (+/- 0.019) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.294 (+/- 0.032) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.294 (+/- 0.028) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'best'}
# 0.294 (+/- 0.013) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'random'}
# 0.294 (+/- 0.033) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.294 (+/- 0.036) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.294 (+/- 0.022) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.294 (+/- 0.028) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 5, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.293 (+/- 0.015) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
# 0.293 (+/- 0.011) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
# 0.293 (+/- 0.016) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.293 (+/- 0.013) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.293 (+/- 0.029) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.293 (+/- 0.01) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.293 (+/- 0.022) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
# 0.293 (+/- 0.023) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
# 0.293 (+/- 0.016) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.293 (+/- 0.012) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.293 (+/- 0.016) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.293 (+/- 0.006) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.293 (+/- 0.013) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'best'}
# 0.293 (+/- 0.02) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'random'}
# 0.293 (+/- 0.021) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.292 (+/- 0.011) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.292 (+/- 0.01) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.292 (+/- 0.023) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 50, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.292 (+/- 0.012) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
# 0.292 (+/- 0.016) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
# 0.292 (+/- 0.008) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.292 (+/- 0.003) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.292 (+/- 0.005) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.292 (+/- 0.018) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.292 (+/- 0.016) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
# 0.291 (+/- 0.013) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
# 0.291 (+/- 0.006) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.291 (+/- 0.028) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.291 (+/- 0.013) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.291 (+/- 0.018) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.291 (+/- 0.009) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'best'}
# 0.291 (+/- 0.004) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'random'}
# 0.291 (+/- 0.009) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.29 (+/- 0.015) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.29 (+/- 0.007) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.29 (+/- 0.01) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': 500, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}
# 0.29 (+/- 0.015) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'best'}
# 0.29 (+/- 0.008) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 1, 'splitter': 'random'}
# 0.289 (+/- 0.018) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}
# 0.289 (+/- 0.016) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'random'}
# 0.289 (+/- 0.016) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'best'}
# 0.288 (+/- 0.006) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 1, 'min_samples_split': 3, 'splitter': 'random'}
# 0.287 (+/- 0.009) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'best'}
# 0.286 (+/- 0.006) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 1, 'splitter': 'random'}
# 0.286 (+/- 0.01) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# 0.286 (+/- 0.011) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'random'}
# 0.286 (+/- 0.017) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'best'}
# 0.285 (+/- 0.015) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 2, 'min_samples_split': 3, 'splitter': 'random'}
# 0.285 (+/- 0.005) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'best'}
# 0.285 (+/- 0.008) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 1, 'splitter': 'random'}
# 0.284 (+/- 0.009) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'best'}
# 0.284 (+/- 0.014) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 2, 'splitter': 'random'}
# 0.283 (+/- 0.016) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'best'}
# 0.283 (+/- 0.009) for {'criterion': 'log_loss', 'max_depth': None, 'max_features': 'log2', 'max_leaf_nodes': None, 'min_samples_leaf': 3, 'min_samples_split': 3, 'splitter': 'random'}

# %%
# best params
dt0 = DecisionTreeClassifier(criterion='entropy', max_depth=50, max_features=None, max_leaf_nodes=50, min_samples_leaf=1, min_samples_split=1, splitter='best')
dt0scores = cross_val_score(dt0, tr_features, tr_labels.values.ravel(), cv=5, n_jobs=-1)
print(dt0scores)
dt0.fit(tr_features, tr_labels.values.ravel())

dt1 = DecisionTreeClassifier(max_depth=5, max_leaf_nodes=5, min_samples_split=1)
dt1scores = cross_val_score(dt1, tr_features, tr_labels.values.ravel(), cv=5, n_jobs=-1)
print(dt1scores)
dt1.fit(tr_features, tr_labels.values.ravel())

# dt2 = DecisionTreeClassifier(max_depth=5, max_leaf_nodes=5)
# dt2scores = cross_val_score(dt2, tr_features, tr_labels.values.ravel(), cv=5, n_jobs=-1)
# print(dt2scores)
# dt2.fit(tr_features, tr_labels.values.ravel())

dt2 = DecisionTreeClassifier(max_depth=None, max_leaf_nodes=50)
dt2scores = cross_val_score(dt2, tr_features, tr_labels.values.ravel(), cv=5, n_jobs=-1)
print(dt2scores)
dt2.fit(tr_features, tr_labels.values.ravel())

for mdl in [dt, dt0, dt1, dt2]:
    y_pred = mdl.predict(te_features)
    accuracy = round(accuracy_score(te_labels, y_pred), 8)
    precision = round(precision_score(te_labels, y_pred, average='weighted'), 8)
    recall = round(recall_score(te_labels, y_pred, average='weighted'), 8)
    f1 = round(f1_score(te_labels, y_pred, average='weighted'), 8)
    print(f'MAX DEPTH: {mdl.max_depth} / MAX LEAF NODES: {mdl.max_leaf_nodes} / A: {accuracy} / P: {precision} / R: {recall} / F1: {f1}')
# Out:
# [0.36528457 0.37364023 0.372379   0.36418099 0.35708655]
# [0.34337064 0.35409112 0.34794261 0.34794261 0.34195176]
# [0.35945136 0.37159073 0.36039729 0.36355037 0.36686111]
# MAX DEPTH: None / MAX LEAF NODES: None / A: 0.31012738 / P: 0.31088201 / R: 0.31012738 / F1: 0.31044495
# MAX DEPTH: 50 / MAX LEAF NODES: 50 / A: 0.38289822 / P: 0.36930244 / R: 0.38289822 / F1: 0.35612188
# MAX DEPTH: 5 / MAX LEAF NODES: 5 / A: 0.35187287 / P: 0.25495474 / R: 0.35187287 / F1: 0.28493377
# MAX DEPTH: None / MAX LEAF NODES: 50 / A: 0.3723042 / P: 0.36190958 / R: 0.3723042 / F1: 0.36016537
# c:\Users\zhutz\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
