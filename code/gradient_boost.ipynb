# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import GradientBoostingClassifier, HistGradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
pd.set_option('display.max_columns', None)

# %%
tr_features = pd.read_csv('data/train_features.csv')
tr_labels = pd.read_csv('data/train_labels.csv')

te_features = pd.read_csv('data/test_features.csv')
te_labels = pd.read_csv('data/test_labels.csv')

# %%
def print_results(results):
    print(f'BEST PARAMS: {results.best_params_}\n')

    means = sorted(results.cv_results_['mean_test_score'], reverse=True)
    stds = results.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, results.cv_results_['params']):
        print(f'{round(mean,3)} (+/- {round(std * 2, 3)}) for {params}')

# %%
# gb = GradientBoostingClassifier()
# gbscores = cross_val_score(gb, tr_features, tr_labels.values.ravel(), cv=5, n_jobs=16)

# print(gbscores)
# gb.fit(tr_features, tr_labels.values.ravel())

gb = HistGradientBoostingClassifier()
gbscores = cross_val_score(gb, tr_features, tr_labels.values.ravel(), cv=5, n_jobs=32)

print(gbscores)
gb.fit(tr_features, tr_labels.values.ravel())
# Out:
# [0.38562195 0.40327921 0.38704083 0.3857796  0.39003626]
# HistGradientBoostingClassifier()

# %%
# gbparams = {
#     'loss': ['log_loss', 'deviance', 'exponential'],
#     'n_estimators': [10, 50],
#     'criterion': ['friedman_mse', 'squared_error'],
#     'max_features': ['sqrt', 'log2', None],
#     'warm_start': [True, False]
# }
# cv = GridSearchCV(gb, gbparams, cv=5, n_jobs=16)
# cv.fit(tr_features, tr_labels.values.ravel())

gbparams = {
    'learning_rate': [0.1,0.5,1.0],
    'max_iter': [100,200,500],
    'max_leaf_nodes': [16,31,None],
    'max_depth': [100,500,None],
    'min_samples_leaf': [20,50,100],
    'l2_regularization': [0,1]
}

cv = GridSearchCV(gb, gbparams, cv=5, n_jobs=32)
cv.fit(tr_features, tr_labels.values.ravel())

print_results(cv)
# Out:
# BEST PARAMS: {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
#
# 0.397 (+/- 0.015) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.397 (+/- 0.013) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.396 (+/- 0.014) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.396 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.396 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.395 (+/- 0.013) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.395 (+/- 0.006) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.395 (+/- 0.013) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.395 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.395 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.395 (+/- 0.013) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.395 (+/- 0.013) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.395 (+/- 0.015) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.395 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.395 (+/- 0.014) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.394 (+/- 0.005) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.394 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.394 (+/- 0.014) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.394 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.394 (+/- 0.006) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.394 (+/- 0.015) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.394 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.394 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.394 (+/- 0.013) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.394 (+/- 0.003) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.394 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.394 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.394 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.394 (+/- 0.007) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.394 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.394 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.393 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.393 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.393 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.393 (+/- 0.005) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.393 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.393 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.393 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.393 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.393 (+/- 0.015) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.393 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.393 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.393 (+/- 0.004) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.393 (+/- 0.005) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.393 (+/- 0.014) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.393 (+/- 0.014) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.393 (+/- 0.013) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.393 (+/- 0.015) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.393 (+/- 0.006) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.393 (+/- 0.015) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.393 (+/- 0.013) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.393 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.393 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.392 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.392 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.392 (+/- 0.007) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.392 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.392 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.392 (+/- 0.014) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.392 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.392 (+/- 0.007) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.392 (+/- 0.015) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.392 (+/- 0.019) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.392 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.392 (+/- 0.017) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.392 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.392 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.392 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.392 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.392 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.392 (+/- 0.015) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.392 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.392 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.391 (+/- 0.014) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.391 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.391 (+/- 0.007) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.391 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.391 (+/- 0.006) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.391 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.391 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.391 (+/- 0.004) for {'l2_regularization': 0, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.391 (+/- 0.004) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.391 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.391 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.391 (+/- 0.007) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.391 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.391 (+/- 0.017) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.391 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.391 (+/- 0.018) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.39 (+/- 0.007) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.39 (+/- 0.005) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.39 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.39 (+/- 0.017) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.39 (+/- 0.007) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.39 (+/- 0.014) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.39 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.39 (+/- 0.004) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.39 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.39 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.39 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.39 (+/- 0.004) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.39 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.39 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.39 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.389 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.389 (+/- 0.007) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.389 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.388 (+/- 0.013) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.387 (+/- 0.006) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.386 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.386 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.385 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.385 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.384 (+/- 0.004) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.384 (+/- 0.016) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.384 (+/- 0.007) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.383 (+/- 0.007) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.383 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.383 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.382 (+/- 0.005) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.381 (+/- 0.014) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.381 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.381 (+/- 0.003) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.381 (+/- 0.007) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.381 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.381 (+/- 0.007) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.38 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.38 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.379 (+/- 0.014) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.379 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.379 (+/- 0.006) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.379 (+/- 0.016) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.379 (+/- 0.007) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.379 (+/- 0.005) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.379 (+/- 0.007) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.379 (+/- 0.007) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.379 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.379 (+/- 0.006) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.378 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.378 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.378 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.378 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.378 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.378 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.378 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.378 (+/- 0.013) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.378 (+/- 0.006) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.378 (+/- 0.007) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.378 (+/- 0.014) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.378 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.377 (+/- 0.006) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.377 (+/- 0.005) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.377 (+/- 0.015) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.377 (+/- 0.017) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.377 (+/- 0.004) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.377 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.377 (+/- 0.007) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.377 (+/- 0.005) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.377 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.377 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.377 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.377 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.376 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.376 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.376 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.376 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.376 (+/- 0.014) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.376 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.376 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.376 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.376 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.376 (+/- 0.007) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.376 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.375 (+/- 0.014) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.375 (+/- 0.005) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.375 (+/- 0.006) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.375 (+/- 0.006) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.375 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.375 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.375 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.374 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.374 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.374 (+/- 0.013) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.374 (+/- 0.007) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.374 (+/- 0.007) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.374 (+/- 0.014) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.374 (+/- 0.014) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.374 (+/- 0.006) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.374 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.374 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.374 (+/- 0.016) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.373 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.373 (+/- 0.006) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.373 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.373 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.373 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.373 (+/- 0.005) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.373 (+/- 0.019) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.373 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.373 (+/- 0.014) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.373 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.373 (+/- 0.017) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.373 (+/- 0.003) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.372 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.372 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.372 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.372 (+/- 0.015) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.372 (+/- 0.016) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.372 (+/- 0.006) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.372 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.372 (+/- 0.019) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.372 (+/- 0.006) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.372 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.372 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.372 (+/- 0.014) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.371 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.371 (+/- 0.016) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.371 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.371 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.371 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.371 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.371 (+/- 0.006) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.371 (+/- 0.005) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.371 (+/- 0.006) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.37 (+/- 0.014) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.37 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.37 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.37 (+/- 0.008) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.37 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.37 (+/- 0.014) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.37 (+/- 0.005) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.37 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.37 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.369 (+/- 0.01) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.369 (+/- 0.009) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.369 (+/- 0.006) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.369 (+/- 0.012) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.369 (+/- 0.004) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.369 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.368 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.368 (+/- 0.011) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.368 (+/- 0.006) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.368 (+/- 0.013) for {'l2_regularization': 0, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.368 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.368 (+/- 0.015) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.368 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.368 (+/- 0.012) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.368 (+/- 0.011) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.368 (+/- 0.007) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.367 (+/- 0.007) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.367 (+/- 0.016) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.367 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.367 (+/- 0.012) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.367 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.367 (+/- 0.014) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.367 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.367 (+/- 0.011) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.367 (+/- 0.006) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.367 (+/- 0.006) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.366 (+/- 0.014) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.366 (+/- 0.012) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.366 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.365 (+/- 0.007) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.365 (+/- 0.008) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.365 (+/- 0.014) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.365 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.365 (+/- 0.007) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.364 (+/- 0.016) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.364 (+/- 0.006) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.362 (+/- 0.012) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.361 (+/- 0.014) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.361 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.36 (+/- 0.002) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.36 (+/- 0.014) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.36 (+/- 0.005) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.359 (+/- 0.015) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.358 (+/- 0.008) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.358 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.358 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.357 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.357 (+/- 0.011) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.357 (+/- 0.011) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.357 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.357 (+/- 0.011) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.357 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.357 (+/- 0.007) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.357 (+/- 0.007) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.357 (+/- 0.007) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.357 (+/- 0.012) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.357 (+/- 0.011) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.356 (+/- 0.011) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.356 (+/- 0.007) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.356 (+/- 0.012) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.356 (+/- 0.006) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.356 (+/- 0.008) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.356 (+/- 0.011) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.356 (+/- 0.011) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.356 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.356 (+/- 0.014) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.356 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.356 (+/- 0.007) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.355 (+/- 0.005) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.355 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.355 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.355 (+/- 0.003) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.355 (+/- 0.011) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.355 (+/- 0.012) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.355 (+/- 0.011) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.354 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.354 (+/- 0.015) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.354 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.354 (+/- 0.011) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.354 (+/- 0.006) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.354 (+/- 0.013) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.354 (+/- 0.008) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.354 (+/- 0.014) for {'l2_regularization': 1, 'learning_rate': 0.1, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# ...
# 0.346 (+/- 0.014) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.346 (+/- 0.014) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.346 (+/- 0.02) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.346 (+/- 0.008) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.346 (+/- 0.006) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.346 (+/- 0.008) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.346 (+/- 0.002) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.346 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.346 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.346 (+/- 0.014) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.346 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.346 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.346 (+/- 0.006) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.345 (+/- 0.007) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.345 (+/- 0.011) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.345 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.345 (+/- 0.015) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.345 (+/- 0.003) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.345 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.345 (+/- 0.007) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.345 (+/- 0.011) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.345 (+/- 0.015) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.345 (+/- 0.012) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.344 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 0.5, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.344 (+/- 0.017) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.344 (+/- 0.008) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.344 (+/- 0.011) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.344 (+/- 0.014) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.344 (+/- 0.014) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.344 (+/- 0.007) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.344 (+/- 0.006) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.344 (+/- 0.017) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.344 (+/- 0.012) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.344 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.344 (+/- 0.007) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.343 (+/- 0.016) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.343 (+/- 0.017) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.343 (+/- 0.011) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.343 (+/- 0.014) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.343 (+/- 0.008) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.342 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.342 (+/- 0.006) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.342 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.342 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.342 (+/- 0.008) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.342 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.342 (+/- 0.006) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.34 (+/- 0.014) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.34 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.34 (+/- 0.012) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.339 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 100, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.339 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.337 (+/- 0.008) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.337 (+/- 0.005) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.336 (+/- 0.013) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.336 (+/- 0.013) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.335 (+/- 0.011) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.334 (+/- 0.012) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.334 (+/- 0.005) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.334 (+/- 0.021) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.334 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.334 (+/- 0.008) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.333 (+/- 0.017) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.332 (+/- 0.011) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.332 (+/- 0.007) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.332 (+/- 0.012) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.332 (+/- 0.021) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.331 (+/- 0.005) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.331 (+/- 0.006) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.331 (+/- 0.014) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.331 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.331 (+/- 0.008) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.331 (+/- 0.006) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.331 (+/- 0.006) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.331 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.33 (+/- 0.012) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.33 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.33 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': 500, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.33 (+/- 0.014) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.33 (+/- 0.017) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.33 (+/- 0.013) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.33 (+/- 0.014) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.329 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.329 (+/- 0.005) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.329 (+/- 0.013) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.329 (+/- 0.004) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.329 (+/- 0.016) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 100, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.328 (+/- 0.008) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.328 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.328 (+/- 0.017) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.328 (+/- 0.013) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.328 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.328 (+/- 0.007) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.328 (+/- 0.011) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.328 (+/- 0.012) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.328 (+/- 0.012) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 200, 'max_leaf_nodes': None, 'min_samples_leaf': 100}
# 0.327 (+/- 0.008) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 20}
# 0.327 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 50}
# 0.327 (+/- 0.009) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 16, 'min_samples_leaf': 100}
# 0.326 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 20}
# 0.326 (+/- 0.006) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 50}
# 0.326 (+/- 0.015) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': 31, 'min_samples_leaf': 100}
# 0.326 (+/- 0.013) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 20}
# 0.325 (+/- 0.015) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 50}
# 0.325 (+/- 0.01) for {'l2_regularization': 1, 'learning_rate': 1.0, 'max_depth': None, 'max_iter': 500, 'max_leaf_nodes': None, 'min_samples_leaf': 100}

# %%
for mdl in [gb]:
    y_pred = mdl.predict(te_features)
    accuracy = round(accuracy_score(te_labels, y_pred), 8)
    precision = round(precision_score(te_labels, y_pred, average='weighted'), 8)
    recall = round(recall_score(te_labels, y_pred, average='weighted'), 8)
    f1 = round(f1_score(te_labels, y_pred, average='weighted'), 8)
    print(f'MAX DEPTH: {mdl.max_depth} / MAX LEAF NODES: {mdl.max_leaf_nodes} / A: {accuracy} / P: {precision} / R: {recall} / F1: {f1}')
# Out:
# MAX DEPTH: None / MAX LEAF NODES: 31 / A: 0.3938706 / P: 0.3830851 / R: 0.3938706 / F1: 0.38270411
